# %%
import pandas as pd

# %% [markdown]
# ## Connecting to google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Reading file

# %%
data_path = 'drive/MyDrive/CI/Numpy, Pandas/D1.csv' # if you add the folder to your google drive, give it your address path
df = pd.read_csv(data_path)
df
# Out:
#     Div        Date   Time       HomeTeam  ... MaxCAHH  MaxCAHA  AvgCAHH AvgCAHA
# 0    D1  16/08/2019  19:30  Bayern Munich  ...    2.04     1.93     1.98    1.91
# 1    D1  17/08/2019  14:30       Dortmund  ...    1.98     2.04     1.91    1.97
# 2    D1  17/08/2019  14:30       Freiburg  ...    1.97     2.06     1.90    1.99
# 3    D1  17/08/2019  14:30     Leverkusen  ...    2.15     1.91     2.03    1.85
# 4    D1  17/08/2019  14:30  Werder Bremen  ...    1.95     2.11     1.89    2.00
# ..   ..         ...    ...            ...  ...     ...      ...      ...     ...
# 301  D1  27/06/2020  14:30     Leverkusen  ...    2.09     1.97     1.99    1.89
# 302  D1  27/06/2020  14:30     M'gladbach  ...    2.00     2.05     1.93    1.95
# 303  D1  27/06/2020  14:30   Union Berlin  ...    1.84     2.15     1.80    2.07
# 304  D1  27/06/2020  14:30  Werder Bremen  ...    1.97     2.05     1.89    1.98
# 305  D1  27/06/2020  14:30      Wolfsburg  ...    2.04     1.98     1.97    1.90
#
# ...

# %% [markdown]
# ## Some Basics

# %%
df.head(8)
# Out:
#   Div        Date   Time       HomeTeam  ... MaxCAHH  MaxCAHA  AvgCAHH AvgCAHA
# 0  D1  16/08/2019  19:30  Bayern Munich  ...    2.04     1.93     1.98    1.91
# 1  D1  17/08/2019  14:30       Dortmund  ...    1.98     2.04     1.91    1.97
# 2  D1  17/08/2019  14:30       Freiburg  ...    1.97     2.06     1.90    1.99
# 3  D1  17/08/2019  14:30     Leverkusen  ...    2.15     1.91     2.03    1.85
# 4  D1  17/08/2019  14:30  Werder Bremen  ...    1.95     2.11     1.89    2.00
# 5  D1  17/08/2019  14:30      Wolfsburg  ...    2.17     1.86     2.09    1.81
# 6  D1  17/08/2019  17:30     M'gladbach  ...    2.02     2.13     1.93    1.95
# 7  D1  18/08/2019  14:30  Ein Frankfurt  ...    1.90     2.20     1.86    2.03
#
# [8 rows x 105 columns]

# %%
df.tail(10)
# Out:
#     Div        Date  ... AvgCAHA                        Home vs Away
# 296  D1  20/06/2020  ...    2.06             Schalke 04 vs Wolfsburg
# 297  D1  27/06/2020  ...    1.88              Augsburg vs RB Leipzig
# 298  D1  27/06/2020  ...    1.98              Dortmund vs Hoffenheim
# 299  D1  27/06/2020  ...    2.07          Ein Frankfurt vs Paderborn
# 300  D1  27/06/2020  ...    2.03              Freiburg vs Schalke 04
# 301  D1  27/06/2020  ...    1.89                 Leverkusen vs Mainz
# 302  D1  27/06/2020  ...    1.95                M'gladbach vs Hertha
# 303  D1  27/06/2020  ...    2.07  Union Berlin vs Fortuna Dusseldorf
# 304  D1  27/06/2020  ...    1.98            Werder Bremen vs FC Koln
# 305  D1  27/06/2020  ...    1.90          Wolfsburg vs Bayern Munich
#
# [10 rows x 106 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Div        Date  ... AvgCAHA                         Home vs Away
# 0    D1  16/08/2019  ...    1.91              Bayern Munich vs Hertha
# 1    D1  17/08/2019  ...    1.97                 Dortmund vs Augsburg
# 2    D1  17/08/2019  ...    1.99                    Freiburg vs Mainz
# 3    D1  17/08/2019  ...    1.85              Leverkusen vs Paderborn
# 4    D1  17/08/2019  ...    2.00  Werder Bremen vs Fortuna Dusseldorf
# ..   ..         ...  ...     ...                                  ...
# 301  D1  27/06/2020  ...    1.89                  Leverkusen vs Mainz
# 302  D1  27/06/2020  ...    1.95                 M'gladbach vs Hertha
# 303  D1  27/06/2020  ...    2.07   Union Berlin vs Fortuna Dusseldorf
# 304  D1  27/06/2020  ...    1.98             Werder Bremen vs FC Koln
# 305  D1  27/06/2020  ...    1.90           Wolfsburg vs Bayern Munich
#
# [306 rows x 106 columns]>

# %%
print(df.columns)
df['Time']
# Out:
# Index(['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR',
#        'HTHG', 'HTAG',
#        ...
#        'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH',
#        'MaxCAHA', 'AvgCAHH', 'AvgCAHA'],
#       dtype='object', length=105)
# 0      19:30
# 1      14:30
# 2      14:30
# 3      14:30
# 4      14:30
#        ...
# 301    14:30
# 302    14:30
# 303    14:30
# 304    14:30
# 305    14:30
# Name: Time, Length: 306, dtype: object

# %% [markdown]
# ## Sorting Data

# %%
df.sort_values(['HomeTeam', 'AwayTeam'], ascending=[1, 1])
df
# Out:
#     Div        Date   Time       HomeTeam  ... MaxCAHH  MaxCAHA  AvgCAHH AvgCAHA
# 0    D1  16/08/2019  19:30  Bayern Munich  ...    2.04     1.93     1.98    1.91
# 1    D1  17/08/2019  14:30       Dortmund  ...    1.98     2.04     1.91    1.97
# 2    D1  17/08/2019  14:30       Freiburg  ...    1.97     2.06     1.90    1.99
# 3    D1  17/08/2019  14:30     Leverkusen  ...    2.15     1.91     2.03    1.85
# 4    D1  17/08/2019  14:30  Werder Bremen  ...    1.95     2.11     1.89    2.00
# ..   ..         ...    ...            ...  ...     ...      ...      ...     ...
# 301  D1  27/06/2020  14:30     Leverkusen  ...    2.09     1.97     1.99    1.89
# 302  D1  27/06/2020  14:30     M'gladbach  ...    2.00     2.05     1.93    1.95
# 303  D1  27/06/2020  14:30   Union Berlin  ...    1.84     2.15     1.80    2.07
# 304  D1  27/06/2020  14:30  Werder Bremen  ...    1.97     2.05     1.89    1.98
# 305  D1  27/06/2020  14:30      Wolfsburg  ...    2.04     1.98     1.97    1.90
#
# ...

# %% [markdown]
# ## Making Changes to the Data

# %%
df['Home vs Away'] = df['HomeTeam'] + ' vs ' + df['AwayTeam']
df['Home vs Away']
# Out:
# 0                  Bayern Munich vs Hertha
# 1                     Dortmund vs Augsburg
# 2                        Freiburg vs Mainz
# 3                  Leverkusen vs Paderborn
# 4      Werder Bremen vs Fortuna Dusseldorf
#                       ...
# 301                    Leverkusen vs Mainz
# 302                   M'gladbach vs Hertha
# 303     Union Berlin vs Fortuna Dusseldorf
# 304               Werder Bremen vs FC Koln
# 305             Wolfsburg vs Bayern Munich
# Name: Home vs Away, Length: 306, dtype: object

# %% [markdown]
# ## Saving Data

# %%
df.to_csv('bundesliga.csv', index=False)

# %% [markdown]
# ## Filtering Data

# %%
df.loc[(df['HomeTeam'] == 'Bayern Munich') & (df['AwayTeam'] == 'Dortmund')]
# Out:
#    Div        Date   Time  ... AvgCAHH AvgCAHA               Home vs Away
# 95  D1  09/11/2019  17:30  ...    1.92    1.95  Bayern Munich vs Dortmund
#
# [1 rows x 106 columns]

# %% [markdown]
# ## Creating DataFrame

# %%
football_data = {
    'Team' : ['Persepolis', 'Barcelona'],
    'Coach': ['Yahya Golmohammadi', 'Ronald Koeman'],
    'Color': ['Red', 'Red'],
    'Rank' : ['86', '17']
}

new_df = pd.DataFrame(football_data1)
print(new_df)

sort_df = new_df.sort_values('Rank')
sort_df
# Out:
#          Team               Coach Color Rank
# 0  Persepolis  Yahya Golmohammadi   Red   86
# 1   Barcelona        Ronald Coman   Red   17
#          Team               Coach Color Rank
# 1   Barcelona        Ronald Coman   Red   17
# 0  Persepolis  Yahya Golmohammadi   Red   86
